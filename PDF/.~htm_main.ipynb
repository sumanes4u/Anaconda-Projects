# %%
from urllib.request import urlopen 

my_address = "http://help.websiteos.com/websiteos/example_of_a_simple_html_page.htm"

html_page = urlopen(my_address)

html_text = html_page.read().decode('utf-8')

print (html_text)
# Out:
# <!doctype HTML public "-//W3C//DTD HTML 4.0 Frameset//EN">
#
# <!-- saved from url=(0014)about:internet -->
# <html>
#
# <head>
# <meta http-equiv="content-type" content="text/html;charset=windows-1252">
# <title>Example of a simple HTML page</title>
# <meta name="generator" content="Adobe RoboHelp - www.adobe.com">
# <link rel="stylesheet" href="default_ns.css"><script type="text/javascript" language="JavaScript" title="WebHelpSplitCss">
# <!--
# if (navigator.appName !="Netscape")
# {   document.write("<link rel='stylesheet' href='default.css'>");}
# //-->
# </script>
# <style type="text/css">
# <!--
# img_whs1 { border:none; width:301px; height:295px; float:none; }
# p.whs2 { margin-bottom:5pt; }
# p.whs3 { margin-bottom:9.5pt; }
# -->
# </style><script type="text/javascript" language="JavaScript" title="WebHelpInlineScript">
# <!--
# function reDo() {
#   if (innerWidth != origWidth || innerHeight != origHeight)
#      location.reload();
# }
# ...

# %%
from urllib.request import urlopen 

my_address = "https://facebook.com"

html_page = urlopen(my_address)

html_text = html_page.read().decode('utf-8')

print (html_text)
# Out:
# <!DOCTYPE html>
# <html lang="kn" id="facebook" class="no_js">
# ...

# %%
from urllib.request import urlopen 

my_address = "http://help.websiteos.com/websiteos/example_of_a_simple_html_page.htm"

html_page = urlopen(my_address)

html_text = html_page.read().decode('utf-8')

start_tag = "<title>"

end_tag = "</title>"

start_index = html_text.find(start_tag) + len(start_tag)

end_index = html_text.find(end_tag)

print (html_text[start_index:end_index])
# Out:
# Example of a simple HTML page

# %%
import re

# %%
re.findall("ab*c","ac")
# Out:
# ['ac']

# %%
re.findall("ab*c","abcd")
# Out:
# ['abc']

# %%
re.findall("ab*c","acc")
# Out:
# ['ac']

# %%
re.findall("ab*c","abcac")
# Out:
# ['abc', 'ac']

# %%
re.findall("ab*c","abdc")
# Out:
# []

# %%
re.findall("ab*c","ABC")
# Out:
# []

# %%
re.findall("ab*c","ABC",re.IGNORECASE)
# Out:
# ['ABC']

# %%
re.findall("a.c","abc")
# Out:
# ['abc']

# %%
re.findall("a.c","abbc")
# Out:
# []

# %%
re.findall("a.c","ac")
# Out:
# []

# %%
re.findall("a.c","acc")
# Out:
# ['acc']

# %%
re.findall("a.*c","abc")
# Out:
# ['abc']

# %%
re.findall("a.*c","abbc")
# Out:
# ['abbc']

# %%
re.findall("a.*c","ac")
# Out:
# ['ac']

# %%
re.findall("a.*c","acc")
# Out:
# ['acc']

# %%
match_results = re.search("ab*c","ABC",re.IGNORECASE)

# %%
print (match_results.group())
# Out:
# ABC

# %%
my_string = "Everything is <replaced> if it's in <tags>."

# %%
my_string = re.sub("<.*>","ELEPHANTS2",my_string)

# %%
print (my_string)
# Out:
# Everything is ELEPHANTS2.

# %%
my_string = "Everything is <replaced> if it's in <tags>."

# %%
my_string = re.sub("<.*?>","ELEPHANTS2",my_string)

# %%
print (my_string)
# Out:
# Everything is ELEPHANTS2 if it's in ELEPHANTS2.

# %%
# ex.

import re
from urllib.request import urlopen

my_address = "file:///Users/aws/Dionysus.html"

html_page = urlopen(my_address)
html_text = html_page.read().decode('utf-8')

match_results = re.search("<title.*?>.*</title.*?>",html_text, re.IGNORECASE)

title = match_results.group()

title = re.sub("<.*?>", "", title)

print (title)
# Out:
# Profile: Dionysus

# %%
#ex

from bs4 import BeautifulSoup
from urllib.request import urlopen

my_address = "file:///Users/aws/Dionysus.html"

html_page = urlopen(my_address)
html_text = html_page.read().decode("utf-8")

my_soup = BeautifulSoup(html_text)
print (my_soup.get_text())
# Out:
# Profile: Dionysus
#
#
#
#
#
# Name: Dionysus
#
# Hometown: Mount Olympus
#
# Favorite animal: Leopard
#
# Favorite Color: Wine
# /Users/aws/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/aws/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
print (my_soup.find_all("img"))
# Out:
# [<img src="/static/practice/dionysus.965b7ed69b53.jpg"/>, <img src="/static/practice/grapes.477944afc362.png"/>]

# %%
print (my_soup.title)
# Out:
# <title>Profile: Dionysus</title>

# %%
print (my_soup.title.string)
# Out:
# Profile: Dionysus

# %%
import mechanicalsoup 

my_browser = mechanicalsoup.Browser()

page = my_browser.get("http://help.websiteos.com/websiteos/example_of_a_simple_html_page.htm")

print (page.soup)
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Frameset//EN">
# <!-- saved from url=(0014)about:internet --><html>
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
# <title>Example of a simple HTML page</title>
# <meta content="Adobe RoboHelp - www.adobe.com" name="generator"/>
# <link href="default_ns.css" rel="stylesheet"/><script language="JavaScript" title="WebHelpSplitCss" type="text/javascript">
# <!--
# if (navigator.appName !="Netscape")
# {   document.write("<link rel='stylesheet' href='default.css'>");}
# //-->
# </script>
# <style type="text/css">
# <!--
# img_whs1 { border:none; width:301px; height:295px; float:none; }
# p.whs2 { margin-bottom:5pt; }
# p.whs3 { margin-bottom:9.5pt; }
# -->
# </style><script language="JavaScript" title="WebHelpInlineScript" type="text/javascript">
# <!--
# function reDo() {
#   if (innerWidth != origWidth || innerHeight != origHeight)
#      location.reload();
# }
# ...

# %%
# ex

import mechanicalsoup 

my_browser = mechanicalsoup.Browser()

page = my_browser.get("https://realpython.com/practice/login.php")

print (page.soup)
# Out:
# <html>
# <head>
# <title>Log In</title>
# </head>
# <body bgcolor="yellow">
# <center>
# <br/><br/>
# <h2>Please log in to access Mount Olympus:</h2>
# <br/><br/>
# <form action="login.php" method="post" name="login">
# Username: <input name="user" type="text"/><br/>
# Password: <input name="pwd" type="password"/><br/><br/>
# <input type="submit" value="Submit"/>
# </form>
# </center>
# </body>
# </html>

# %%
# ex 

import mechanicalsoup 

my_browser = mechanicalsoup.Browser()

login_page = my_browser.get("https://realpython.com/practice/login.php")

login_html = login_page.soup

# 

form = login_html.select("form")[0]
form.select("input")[0]["value"] = "zeus"
form.select("input")[1]["value"] = "ThunderDude"

profiles_page = my_browser.submit(form,login_page.url)

print(profiles_page.url)
print (profiles_page.soup)
# Out:
# https://realpython.com/practice/profiles.html
# <html>
# <head>
# <title>All Profiles</title>
# </head>
# <body bgcolor="yellow">
# <center>
# <br/><br/>
# <h1>All Profiles:</h1>
# <br/><br/>
# <h2>
# <a href="aphrodite.html">Aphrodite</a>
# <br/><br/>
# <a href="poseidon.html">Poseidon</a>
# <br/><br/>
# <a href="dionysus.html">Dionysus</a>
# </h2>
# </center>
# </body>
# </html>

# %%
# ex : 

import mechanicalsoup 

my_browser = mechanicalsoup.Browser()

page = my_browser.get("http://finance.yahoo.com/q?s=yahoo")

html_text = page.soup

my_tags = html_text.select('#yfs_184_yhoo')

print (my_tags)
#my_price = my_tags[1].text

#print ('The current price of YHOO is: {}'.format(my_price))
# Out:
# []
